# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
complaints_dec14 = pd.read_csv('complaints_dec_2014.csv')

# %%
complaints_dec14['Product'].value_counts().plot("bar")

# %%
complaints_dec14['Company'].value_counts()[:10].plot("bar")

# %%
complaints_dec14['Company response'].value_counts().plot("bar")

# %%
complaints_dec14.index = pd.to_datetime(complaints_dec14['Date received'], '%m/%d/%Y')

# %%
complaints_dec14['weekday'] = complaints_dec14.index.weekday
#complaints_dec14['weekday'] = complaints_dec14.index.to_series().map(lambda d: d.weekday())

# %%
complaints_dec14.index.groupby(lambda x: x.weekday).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-c80f0beca842> in <module>()
# ----> 1 complaints_dec14.index.groupby(lambda x: x.weekday).mean()
#
# /Users/jonathanfrederick/tiy/week4/consumer-complaints/.direnv/python-3.4.3/lib/python3.4/site-packages/pandas/tseries/base.py in groupby(self, f)
#      58     def groupby(self, f):
#      59         objs = self.asobject.values
# ---> 60         return _algos.groupby_object(objs, f)
#      61
#      62     def _format_with_header(self, header, **kwargs):
#
# TypeError: Argument 'labels' has incorrect type (expected numpy.ndarray, got function)

# %%
complaints_dec14['weekday'].unique().index.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-c9ed90758305> in <module>()
# ----> 1 complaints_dec14['weekday'].unique().index.unique()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
print(complaints_dec14.index.value_counts())
print(complaints_dec14.index)
# Out:
# Date received
# 2014-12-04    571
# 2014-12-10    570
# 2014-12-30    550
# 2014-12-17    539
# 2014-12-22    537
# 2014-12-29    532
# 2014-12-18    527
# 2014-12-08    526
# 2014-12-02    516
# 2014-12-16    510
# 2014-12-09    503
# 2014-12-23    501
# 2014-12-03    494
# 2014-12-11    484
# 2014-12-15    475
# 2014-12-01    474
# 2014-12-12    428
# 2014-12-05    426
# 2014-12-31    371
# 2014-12-19    363
# 2014-12-24    315
# 2014-12-26    229
# 2014-12-28    164
# 2014-12-20    148
# 2014-12-06    147
# 2014-12-13    144
# 2014-12-14    130
# 2014-12-07    117
# 2014-12-27    104
# 2014-12-21     96
# 2014-12-25     52
# dtype: int64
# DatetimeIndex(['2014-12-31', '2014-12-31', '2014-12-31', '2014-12-31',
#                '2014-12-31', '2014-12-31', '2014-12-31', '2014-12-31',
#                '2014-12-31', '2014-12-31',
#                ...
#                '2014-12-01', '2014-12-01', '2014-12-01', '2014-12-01',
#                '2014-12-01', '2014-12-01', '2014-12-01', '2014-12-01',
#                '2014-12-01', '2014-12-01'],
#               dtype='datetime64[ns]', name='Date received', length=11543, freq=None, tz=None)

# %%
day_dict = {}
for day in days_sub:
    if day.weekday() in days_sub:
        day_dict[day.weekday()] +=1
    else:
        day_dict[day.weekday()] = 1
day_list = []
day_values = []
for day in day_dict:
    day_list.append(day)
    day_values.append(day_dict[day])

n = len(day_list)
index = np.arange(n)
width = .5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-cb32816aaa3f> in <module>()
#       2 for day in days_sub:
#       3     if day.weekday() in days_sub:
# ----> 4         day_dict[day.weekday()] +=1
#       5     else:
#       6         day_dict[day.weekday()] = 1
#
# KeyError: 2

# %%
plt.bar(index, day_values, width)
plt.ylabel("Count")
plt.xlabel("Day of Week")
plt.xticks(index+width/2., ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], rotation=90)
plt.show()

# %%
date_dict = {}
for date in days_sub:
    if date in date_dict:
        date_dict[date] +=1
    else:
        date_dict[date] = 1
date_list = []
date_values = []
for date in date_dict:
    date_list.append(date.day)
    date_values.append(date_dict[date])

n = len(date_list)
index = np.arange(n)
width = .3
print(date_list)
# Out:
# [26, 17, 20, 19, 16, 28, 12, 12, 7, 14, 6, 22, 20, 1, 23, 2, 24, 9, 13, 31, 22, 14, 16, 18, 9, 11, 23, 2, 21, 8, 4, 13, 10, 29, 21, 6, 27, 26, 30, 25, 15, 7, 5, 10, 1, 3, 8, 15, 5]

# %%
plt.bar(index, date_values, width)
plt.ylabel("Count")
plt.xlabel("Day of Month")
plt.xticks(index+width/2., date_list, rotation=0)
plt.show()

# %%
complaints_dec14.
